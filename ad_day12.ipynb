# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya0786/2311cs020451/blob/main/ad_day12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
k=[4,2,9,87.9999,40]
k
# Out:
# [4, 2, 9, 87.9999, 40]

# %%
pd.Series(k)
# Out:
# 0     4.0000
# 1     2.0000
# 2     9.0000
# 3    87.9999
# 4    40.0000
# dtype: float64

# %%
a=np.random.randint(29,50,15)
a
# Out:
# array([35, 46, 37, 37, 41, 33, 42, 47, 42, 32, 31, 36, 34, 43, 49])

# %%
b=np.random.randint(100,200,(6,5))
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (6, 5)

# %%
b
# Out:
# array([[192, 183, 156, 107, 171],
#        [187, 157, 153, 151, 105],
#        [143, 152, 112, 133, 107],
#        [132, 183, 114, 116, 128],
#        [127, 114, 106, 104, 143],
#        [161, 189, 106, 141, 144]])

# %%
df=pd.DataFrame(b,columns=['Roll','name','age','adds','country'],index=[182,183,184,185,186,187])
df
# Out:
#      Roll  name  age  adds  country
# 182   192   183  156   107      171
# 183   187   157  153   151      105
# 184   143   152  112   133      107
# 185   132   183  114   116      128
# 186   127   114  106   104      143
# 187   161   189  106   141      144

# %%
df.iloc[0,0]
# Out:
# 192

# %%
df.loc[182,['Roll','name','age']]
# Out:
# Roll    192
# name    183
# age     156
# Name: 182, dtype: int64

# %%
df.loc[[182,183,184],['Roll','name','age']]
# Out:
#      Roll  name  age
# 182   192   183  156
# 183   187   157  153
# 184   143   152  112
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['Roll'].plot(kind='hist', bins=20, title='Roll')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['name'].plot(kind='hist', bins=20, title='name')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='Roll', y='name', s=32, alpha=.8)
# ...

# %%
df.age
# Out:
# 182    156
# 183    153
# 184    112
# 185    114
# 186    106
# 187    106
# Name: age, dtype: int64

# %%
df['age']
# Out:
# 182    156
# 183    153
# 184    112
# 185    114
# 186    106
# 187    106
# Name: age, dtype: int64

# %%
df[['age','adds']]
# Out:
#      age  adds
# 182  156   107
# 183  153   151
# 184  112   133
# 185  114   116
# 186  106   104
# 187  106   141

# %%
df.loc[[182,183,184],['age','adds']]
# Out:
#      age  adds
# 182  156   107
# 183  153   151
# 184  112   133

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('healthexp')
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6, 5)

# %%
df.columns
# Out:
# Index(['Roll', 'name', 'age', 'adds', 'country'], dtype='object')
